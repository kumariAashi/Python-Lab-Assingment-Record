# %%
#wap to find following using math module

# %%
#square root of number
import math

# Input from user
num = float(input("Enter a number: "))
print("Enter a number:",num)

# Square root
result = math.sqrt(num)

# Output
print("Square root of", num, "is:", result)
# Out:
# Enter a number: 2.0
# Square root of 2.0 is: 1.4142135623730951

# %%
#Factorial of a number
import math

# Input from user
num = int(input("Enter a number: "))
print("Enter a number:",num)

# Factorial
result = math.factorial(num)

# Output
print("Factorial of", num, "is:", result)
# Out:
# Enter a number: 5
# Factorial of 5 is: 120

# %%
#power of number
import math

# Input from user
base = float(input("Enter the base number: "))
print("Enter the base number:",base)
exponent = float(input("Enter the exponent: "))
print("Enter the exponent:",exponent)

# Power calculation
result = math.pow(base, exponent)

# Output
print(base, "raised to the power", exponent, "is:", result)
# Out:
# Enter the base number: 4.0
# Enter the exponent: 2.0
# 4.0 raised to the power 2.0 is: 16.0
